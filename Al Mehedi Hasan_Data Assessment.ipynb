# %%
import pandas as pd
import seaborn as sns
import matplotlib as plt

# %%
df = pd.read_csv(r"C:\Users\Hp\Downloads\Assesment Data.csv")

# %%
df
# Out:
#             login    ticket  symbol  type            open_time  \
# 0        11173702  47345780  XAUUSD   Buy  2024.07.30 11:05:29
# 1        11173702  47718163  XAUUSD   Buy  2024.07.31 09:46:04
# 2        11173702  50360070  XAUUSD  Sell  2024.08.13 13:03:27
# 3        11173702  51120570  XAUUSD   Buy  2024.08.19 13:27:40
# 4        11173702  52180073  XAUUSD  Sell  2024.08.28 02:30:32
# ...           ...       ...     ...   ...                  ...
# 59312  2145732336   2412502  NZDUSD  sell  2024.11.07 11:23:51
# 59313  2145732336   2426484  GBPNZD   buy  2024.11.11 14:41:30
# 59314  2145732336   2433467  GBPNZD   buy  2024.11.12 15:30:58
# 59315  2145732336   2437184  EURGBP  sell  2024.11.13 09:40:04
# 59316  2145732336   2444120  GBPJPY   buy  2024.11.14 10:22:55
#
#                 close_time  open_price  close_price   stop loss  take profit  \
# 0       2024-07-31 7:58:09  2391.28000   2420.69000  2367.62000     2420.640
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59317 entries, 0 to 59316
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   login        59317 non-null  int64
#  1   ticket       59317 non-null  int64
#  2   symbol       59317 non-null  object
#  3   type         59317 non-null  object
#  4   open_time    59317 non-null  object
#  5   close_time   59317 non-null  object
#  6   open_price   59317 non-null  float64
#  7   close_price  59317 non-null  float64
#  8   stop loss    59317 non-null  float64
#  9   take profit  59317 non-null  float64
#  10  pips         59317 non-null  float64
#  11  reason       59317 non-null  int64
#  12  volume       59317 non-null  int64
#  13  profit       59317 non-null  float64
# dtypes: float64(6), int64(4), object(4)
# memory usage: 6.3+ MB

# %%
df.duplicated().any()
# Out:
# False

# %%
see_duplicate = df[df.duplicated()]
see_duplicate
# Out:
# Empty DataFrame
# Columns: [login, ticket, symbol, type, open_time, close_time, open_price, close_price, stop loss, take profit, pips, reason, volume, profit]
# Index: []

# %%
for i in df.select_dtypes(include="object").columns:
    print(df[i].value_counts())
    print("*"*20)
# Out:
# symbol
# XAUUSD    28887
# EURUSD     6196
# US30       4313
# GBPUSD     3133
# NDX100     2577
#           ...
# AUDSGD        2
# MXNJPY        2
# NTH25         2
# XMRUSD        1
# USDTRY        1
# Name: count, Length: 63, dtype: int64
# ********************
# type
# Buy     25647
# Sell    21577
# buy      7069
# sell     5024
# Name: count, dtype: int64
# ********************
# open_time
# 2024.11.19 12:09:11    34
# 2024.11.07 07:49:07    29
# 2024.11.08 13:46:07    17
# 2024.11.07 16:26:15    13
# 2024.12.31 17:13:17    11
#                        ..
# 2024.12.06 11:13:02     1
# 2024.12.06 11:13:23     1
# 2024.12.06 12:34:31     1
# 2024.12.06 12:35:46     1
# 2024.11.14 10:22:55     1
# Name: count, Length: 54069, dtype: int64
# ********************
# close_time
# 1970-01-01 2:00:00     194
# 1970.01.01 00:00:00    145
# 2025-01-31 16:34:30    117
# 2025-01-30 17:03:38     82
# 2025-01-17 19:06:55     60
#                       ...
# 2024-11-27 15:01:20      1
# ...

# %%
df.isnull().sum()
# Out:
# login          0
# ticket         0
# symbol         0
# type           0
# open_time      0
# close_time     0
# open_price     0
# close_price    0
# stop loss      0
# take profit    0
# pips           0
# reason         0
# volume         0
# profit         0
# dtype: int64

# %%
df.shape
# Out:
# (59317, 14)

# %%
df.columns
# Out:
# Index(['login', 'ticket', 'symbol', 'type', 'open_time', 'close_time',
#        'open_price', 'close_price', 'stop loss', 'take profit', 'pips',
#        'reason', 'volume', 'profit'],
#       dtype='object')

# %%
df.dtypes
# Out:
# login            int64
# ticket           int64
# symbol          object
# type            object
# open_time       object
# close_time      object
# open_price     float64
# close_price    float64
# stop loss      float64
# take profit    float64
# pips           float64
# reason           int64
# volume           int64
# profit         float64
# dtype: object

# %%
df.nunique()
# Out:
# login            600
# ticket         59279
# symbol            63
# type               4
# open_time      54069
# close_time     45022
# open_price     39828
# close_price    35853
# stop loss      23025
# take profit    19100
# pips           11639
# reason             8
# volume           817
# profit         25514
# dtype: int64

# %%
df.describe()
# Out:
#               login        ticket     open_price    close_price  \
# count  5.931700e+04  5.931700e+04   59317.000000   59317.000000
# mean   4.274373e+07  4.820009e+07    9247.848230    9249.311204
# std    2.126909e+08  2.781208e+07   20700.786785   20702.285285
# min    1.117370e+07  7.631230e+05       0.308400       0.325050
# 25%    1.318703e+07  2.785692e+07      70.730000      70.940000
# 50%    1.327834e+07  5.709664e+07    2645.190000    2645.790000
# 75%    1.340079e+07  7.241683e+07    2755.480000    2755.220000
# max    2.145732e+09  8.051714e+07  109111.000000  108304.000000
#
#            stop loss   take profit          pips        reason         volume  \
# count   59317.000000  5.931700e+04  5.931700e+04  59317.000000   59317.000000
# mean     6119.568535  4.895936e+03  1.115243e+02      7.236711     176.008463
# std     17961.190194  1.736828e+04  3.093160e+04      6.774457    1768.198799
# ...

# %%
df.describe(include = "object")
# Out:
#         symbol   type            open_time          close_time
# count    59317  59317                59317               59317
# unique      63      4                54069               45022
# top     XAUUSD    Buy  2024.11.19 12:09:11  1970-01-01 2:00:00
# freq     28887  25647                   34                 194

# %%
df.corr(numeric_only=True)
# Out:
#                 login    ticket  open_price  close_price  stop loss  \
# login        1.000000 -0.229908   -0.029324    -0.029325  -0.017243
# ticket      -0.229908  1.000000   -0.056911    -0.057037  -0.081876
# open_price  -0.029324 -0.056911    1.000000     0.999888   0.799446
# close_price -0.029325 -0.057037    0.999888     1.000000   0.798975
# stop loss   -0.017243 -0.081876    0.799446     0.798975   1.000000
# take profit -0.015630 -0.040651    0.710189     0.710091   0.663627
# pips        -0.000411 -0.003915   -0.001573     0.007710  -0.047126
# reason      -0.061121  0.313132   -0.110016    -0.109888  -0.139058
# volume      -0.010389 -0.005232   -0.027988    -0.027993  -0.019709
# profit      -0.005339  0.009388   -0.009115    -0.008343  -0.012062
#
#              take profit      pips    reason    volume    profit
# login          -0.015630 -0.000411 -0.061121 -0.010389 -0.005339
# ticket         -0.040651 -0.003915  0.313132 -0.005232  0.009388
# ...

# %%
df.corr(numeric_only=True)["profit"]
# Out:
# login         -0.005339
# ticket         0.009388
# open_price    -0.009115
# close_price   -0.008343
# stop loss     -0.012062
# take profit    0.005967
# pips           0.137911
# reason         0.079314
# volume         0.011749
# profit         1.000000
# Name: profit, dtype: float64

# %%
# data distribution
for i in ['open_price', 'close_price', 'stop loss', 'take profit', 'pips', 'reason', 'volume', 'profit']:
    sns.histplot(data=df,x=i)
    plt.pyplot.show()

# %%
#outliers
for i in ['open_price', 'close_price', 'stop loss', 'take profit', 'pips', 'reason', 'volume', 'profit']:
    sns.boxplot(data=df,x=i)
    plt.pyplot.show()

# %%
df["type"] = df["type"].replace({"sell" : "Sell" , "buy" : "Buy"})
df["type"].unique()
# Out:
# array(['Buy', 'Sell'], dtype=object)

# %%
df['open_time'] = pd.to_datetime(df['open_time'])
df['open_time'] = df['open_time'].dt.strftime('%Y-%m-%d %H:%M:%S')
df['open_time'] = pd.to_datetime(df['open_time'])

# %%
print(df['open_time'].unique())
# Out:
# <DatetimeArray>
# ['2024-07-30 11:05:29', '2024-07-31 09:46:04', '2024-08-13 13:03:27',
#  '2024-08-19 13:27:40', '2024-08-28 02:30:32', '2024-08-29 11:21:25',
#  '2024-09-02 12:29:41', '2024-09-03 13:33:39', '2024-09-09 18:09:18',
#  '2024-09-23 18:34:08',
#  ...
#  '2024-11-05 16:38:54', '2024-11-06 01:45:25', '2024-11-06 09:25:04',
#  '2024-11-06 15:06:27', '2024-11-07 09:17:23', '2024-11-07 11:23:51',
#  '2024-11-11 14:41:30', '2024-11-12 15:30:58', '2024-11-13 09:40:04',
#  '2024-11-14 10:22:55']
# Length: 54069, dtype: datetime64[ns]

# %%
df['close_time'] = pd.to_datetime(df['close_time'], format='mixed', errors='coerce')
df['close_time'] = df['close_time'].dt.strftime('%Y-%m-%d %H:%M:%S')
df['close_time'] = pd.to_datetime(df['close_time'])

# %%
df['close_time'].unique()
# Out:
# <DatetimeArray>
# ['2024-07-31 07:58:09', '2024-07-31 21:42:15', '2024-08-14 15:24:08',
#  '2024-08-19 16:37:12', '2024-08-28 15:29:39', '2024-08-29 12:53:08',
#  '2024-09-03 04:13:46', '2024-09-03 17:19:02', '2024-09-11 09:40:01',
#  '2024-09-24 17:53:18',
#  ...
#  '2024-11-04 21:49:48', '2024-11-04 21:49:51', '2024-11-05 11:25:41',
#  '2024-11-06 21:07:40', '2024-11-06 21:20:18', '2024-11-07 15:08:46',
#  '2024-11-11 21:19:38', '2024-11-12 21:35:38', '2024-11-13 11:58:59',
#  '2024-11-14 12:36:05']
# Length: 44736, dtype: datetime64[ns]

# %%
df["symbol"] = df["symbol"].astype("string")
df["type"] = df["type"].astype("string")
df["login"] = df["login"].astype("string")
df["ticket"] = df["ticket"].astype("string")

# %%
df.dtypes
# Out:
# login          string[python]
# ticket         string[python]
# symbol         string[python]
# type           string[python]
# open_time      datetime64[ns]
# close_time     datetime64[ns]
# open_price            float64
# close_price           float64
# stop loss             float64
# take profit           float64
# pips                  float64
# reason                  int64
# volume                  int64
# profit                float64
# dtype: object

# %%
unique_years_open_time = df['open_time'].dt.year.unique()
unique_years_open_time
# Out:
# array([2024, 2025])

# %%
unique_years_close_time = df['close_time'].dt.year.unique()
unique_years_close_time
# Out:
# array([2024, 2025, 1970])

# %%
df_rows_containing_1970 = df[df['close_time'].dt.year == 1970]
df_rows_containing_1970
# Out:
#             login    ticket  symbol  type           open_time  \
# 674      11202254  59097936  XAUUSD   Buy 2025-02-03 09:35:35
# 2558     13036517  74735617  CADJPY  Sell 2025-01-21 17:29:36
# 2559     13036517  77902864  GBPUSD  Sell 2025-01-28 11:38:50
# 3392     13047696  80463175  USDJPY  Sell 2025-02-03 06:53:09
# 3568     13054222  11192978  GBPUSD  Sell 2024-09-03 18:06:28
# ...           ...       ...     ...   ...                 ...
# 58716    55013375   2727973  EURUSD   Buy 2025-02-03 02:24:30
# 58718    55013375   2728433  XAUUSD   Buy 2025-02-03 04:07:55
# 58719    55013375   2728465  BTCUSD   Buy 2025-02-03 04:11:46
# 58855  2145732335   1927234  XAUUSD   Buy 2024-08-02 12:03:36
# 59166  2145732336   1927267  XAUUSD   Buy 2024-08-02 12:10:41
#
#                close_time   open_price  close_price    stop loss  take profit  \
# 674   1970-01-01 02:00:00   2786.46000   2786.08000   2770.46000   2802.16000
# ...

# %%
df.loc[df['close_time'].dt.year == 1970, 'close_time'] = (
    df['open_time'].dt.date.astype(str) + ' ' + df['close_time'].dt.time.astype(str)
)

df['close_time'] = pd.to_datetime(df['close_time'])

# %%
unique_years_close_time = df['close_time'].dt.year.unique()
unique_years_close_time
# Out:
# array([2024, 2025])

# %%
df
# Out:
#             login    ticket  symbol  type           open_time  \
# 0        11173702  47345780  XAUUSD   Buy 2024-07-30 11:05:29
# 1        11173702  47718163  XAUUSD   Buy 2024-07-31 09:46:04
# 2        11173702  50360070  XAUUSD  Sell 2024-08-13 13:03:27
# 3        11173702  51120570  XAUUSD   Buy 2024-08-19 13:27:40
# 4        11173702  52180073  XAUUSD  Sell 2024-08-28 02:30:32
# ...           ...       ...     ...   ...                 ...
# 59312  2145732336   2412502  NZDUSD  Sell 2024-11-07 11:23:51
# 59313  2145732336   2426484  GBPNZD   Buy 2024-11-11 14:41:30
# 59314  2145732336   2433467  GBPNZD   Buy 2024-11-12 15:30:58
# 59315  2145732336   2437184  EURGBP  Sell 2024-11-13 09:40:04
# 59316  2145732336   2444120  GBPJPY   Buy 2024-11-14 10:22:55
#
#                close_time  open_price  close_price   stop loss  take profit  \
# 0     2024-07-31 07:58:09  2391.28000   2420.69000  2367.62000     2420.640
# ...

# %%
df.dtypes
# Out:
# login          string[python]
# ticket         string[python]
# symbol         string[python]
# type           string[python]
# open_time      datetime64[ns]
# close_time     datetime64[ns]
# open_price            float64
# close_price           float64
# stop loss             float64
# take profit           float64
# pips                  float64
# reason                  int64
# volume                  int64
# profit                float64
# dtype: object

# %%
#1. Conduct an in-depth analysis to identify the most and least profitable logins.

most_profitable = df.loc[df["profit"].idxmax()]
least_profitable = df.loc[df["profit"].idxmin()]

print("Most Profitable Login:\n", most_profitable)
print("\nLeast Profitable Login:\n", least_profitable)
# Out:
# Most Profitable Login:
#  login                     13387006
# ticket                    75588886
# symbol                      USDJPY
# type                          Sell
# open_time      2025-01-23 03:59:36
# close_time     2025-01-24 06:17:30
# open_price                 156.558
# close_price                155.078
# stop loss                      0.0
# take profit                 155.08
# pips                        1478.0
# reason                           4
# volume                        2000
# profit                     19061.1
# Name: 43333, dtype: object
#
# Least Profitable Login:
#  login                     13047591
# ticket                    34731674
# symbol                      XAUUSD
# type                          Sell
# open_time      2024-10-24 05:18:45
# close_time     2024-10-24 15:29:01
# open_price                 2721.73
# close_price                2739.23
# stop loss                  2741.75
# take profit                2719.15
# ...

# %%
#2. Compute cumulative profits per login and rank them based on profitability.
profits_per_login = df.groupby("login")["profit"].sum().reset_index()
profits_per_login["rank"] = profits_per_login["profit"].rank(ascending=False, method="dense")
profits_per_login = profits_per_login.sort_values(by="rank")
profits_per_login = profits_per_login[["rank", "login", "profit"]]

profits_per_login
# Out:
#       rank     login    profit
# 396    1.0  13378390  53891.98
# 514    2.0  55009560  28475.44
# 50     3.0  13088202  27848.61
# 146    4.0  13205503  27049.34
# 40     5.0  13070589  27023.68
# ..     ...       ...       ...
# 193  596.0  13251499 -11405.24
# 23   597.0  13018096 -12194.31
# 542  598.0  55011482 -12215.00
# 329  599.0  13333728 -13868.00
# 61   600.0  13103928 -14778.82
#
# [600 rows x 3 columns]

# %%
df.to_excel(r"C:\Users\Hp\Downloads\Cleaned Assessment Data.xlsx", index = False)
